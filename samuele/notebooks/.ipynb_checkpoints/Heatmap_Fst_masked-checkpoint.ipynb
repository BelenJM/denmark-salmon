# %% [markdown]
# ***Import libraires and data, set up stuff***

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import rpy2.rinterface_lib.callbacks
import logging

from rpy2.robjects import pandas2ri
#import anndata2ri

# %%
# Ignore R warning messages
#Note: this can be commented out to get more verbose R output
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

# Automatically convert rpy2 outputs to pandas dataframes
pandas2ri.activate()
#anndata2ri.activate()
# %load_ext rpy2.ipython

# %%
plt.rcParams['figure.figsize']=(6,6) #rescale figures

# %%
from os import listdir
from os.path import isfile, join

# %%
mypath1 = '../../results_5e5/out_fst/'
fileLists = [mypath1+f.split('.')[0]+'.'+f.split('.')[1]+'.fst.txt' for f in listdir(mypath1) if isfile(join(mypath1, f))]
fileLists = np.unique(fileLists)
dataName = [f.split('.')[0]+'.'+f.split('.')[1] for f in listdir(mypath1) if isfile(join(mypath1, f))]
dataName = np.unique(dataName)
colName_1 = [f.split('.')[0] for f in listdir(mypath1) if isfile(join(mypath1, f))]
colName_2 = [f.split('.')[1] for f in listdir(mypath1) if isfile(join(mypath1, f))]
colName = np.unique(colName_1+colName_2)

# %%
colName
# Out:
# array(['ATR', 'BUR', 'CON', 'COR', 'LAG', 'RB_2000', 'RB_2006', 'RB_2016',
#        'SK_1913', 'SK_1932', 'SK_1938', 'SK_1945', 'SK_1955', 'SK_1992',
#        'SK_1999', 'SK_2008', 'SK_2015', 'SN_1913', 'ST_1913', 'ST_1936',
#        'ST_1945', 'ST_1955', 'ST_2000', 'ST_2005', 'ST_2010', 'VA_1913',
#        'VA_1945', 'VA_2000', 'VA_2006', 'VA_2016'], dtype='<U7')

# %%
data = pd.DataFrame(index=colName, columns=colName)

# %%
colName
# Out:
# array(['ATR', 'BUR', 'CON', 'COR', 'LAG', 'RB_2000', 'RB_2006', 'RB_2016',
#        'SK_1913', 'SK_1932', 'SK_1938', 'SK_1945', 'SK_1955', 'SK_1992',
#        'SK_1999', 'SK_2008', 'SK_2015', 'SN_1913', 'ST_1913', 'ST_1936',
#        'ST_1945', 'ST_1955', 'ST_2000', 'ST_2005', 'ST_2010', 'VA_1913',
#        'VA_1945', 'VA_2000', 'VA_2006', 'VA_2016'], dtype='<U7')

# %%
for fileName, name in zip(fileLists, dataName):
    fst = pd.read_csv(fileName, sep='\t', header=None).loc[0,1]
    xName = name.split('.')[0]
    yName = name.split('.')[1]
    data.loc[xName,yName] = fst

# %%
fileLists
# Out:
# array(['../../results_5e5/out_fst/ATR.BUR.fst.txt',
#        '../../results_5e5/out_fst/ATR.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/ATR.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/ATR.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/BUR.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/BUR.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/CON.ATR.fst.txt',
#        '../../results_5e5/out_fst/CON.BUR.fst.txt',
#        '../../results_5e5/out_fst/CON.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/CON.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/CON.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/CON.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/CON.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/CON.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/CON.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/CON.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/CON.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/CON.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/COR.ATR.fst.txt',
#        '../../results_5e5/out_fst/COR.BUR.fst.txt',
#        '../../results_5e5/out_fst/COR.CON.fst.txt',
#        '../../results_5e5/out_fst/COR.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/COR.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/COR.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/COR.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/COR.SK_1932.fst.txt',
#        '../../results_5e5/out_fst/COR.SK_1938.fst.txt',
#        '../../results_5e5/out_fst/COR.SK_1945.fst.txt',
#        '../../results_5e5/out_fst/COR.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/COR.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/COR.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/COR.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/COR.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/COR.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/COR.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/COR.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/COR.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/COR.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/COR.VA_2000.fst.txt',
#        '../../results_5e5/out_fst/COR.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/COR.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/LAG.ATR.fst.txt',
#        '../../results_5e5/out_fst/LAG.BUR.fst.txt',
#        '../../results_5e5/out_fst/LAG.CON.fst.txt',
#        '../../results_5e5/out_fst/LAG.COR.fst.txt',
#        '../../results_5e5/out_fst/LAG.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/LAG.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/LAG.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/LAG.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/LAG.SK_1932.fst.txt',
#        '../../results_5e5/out_fst/LAG.SK_1938.fst.txt',
#        '../../results_5e5/out_fst/LAG.SK_1945.fst.txt',
#        '../../results_5e5/out_fst/LAG.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/LAG.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/LAG.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/LAG.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/LAG.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/LAG.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/LAG.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/LAG.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/LAG.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/LAG.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/LAG.VA_2000.fst.txt',
#        '../../results_5e5/out_fst/LAG.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/LAG.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.ATR.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.BUR.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.CON.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/RB_2000.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.ATR.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.BUR.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/RB_2016.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.ATR.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.BUR.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.CON.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1913.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.ATR.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.BUR.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.CON.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.SK_1938.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.SK_1945.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1932.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.ATR.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.BUR.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.CON.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1938.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.ATR.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.BUR.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.CON.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.SK_1938.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1945.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.ATR.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.BUR.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.CON.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.COR.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.LAG.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.SK_1932.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.SK_1938.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.SK_1945.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.VA_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.VA_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1955.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1992.ATR.fst.txt',
#        '../../results_5e5/out_fst/SK_1992.BUR.fst.txt',
#        '../../results_5e5/out_fst/SK_1992.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1992.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/SK_1992.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.ATR.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.BUR.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.CON.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_1999.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_2008.BUR.fst.txt',
#        '../../results_5e5/out_fst/SK_2008.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_2008.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.ATR.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.BUR.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.CON.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/SK_2015.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.ATR.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.BUR.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.CON.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.COR.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.LAG.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.SK_1932.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.SK_1938.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.SK_1945.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.SK_1955.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.ST_2005.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.VA_1913.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.VA_1945.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.VA_2000.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/SN_1913.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/ST_1913.ATR.fst.txt',
#        '../../results_5e5/out_fst/ST_1913.BUR.fst.txt',
#        '../../results_5e5/out_fst/ST_1913.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_1913.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/ST_1913.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/ST_1913.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/ST_1913.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/ST_1913.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/ST_1913.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_1936.ATR.fst.txt',
#        '../../results_5e5/out_fst/ST_1936.BUR.fst.txt',
#        '../../results_5e5/out_fst/ST_1936.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_1936.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/ST_1936.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/ST_1936.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/ST_1945.ATR.fst.txt',
#        '../../results_5e5/out_fst/ST_1945.BUR.fst.txt',
#        '../../results_5e5/out_fst/ST_1945.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_1945.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/ST_1945.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/ST_1945.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/ST_1945.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/ST_1945.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/ST_1945.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/ST_1945.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_1955.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_2000.ATR.fst.txt',
#        '../../results_5e5/out_fst/ST_2000.BUR.fst.txt',
#        '../../results_5e5/out_fst/ST_2000.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_2000.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/ST_2000.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/ST_2000.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/ST_2000.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/ST_2000.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.ATR.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.BUR.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.CON.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.COR.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.LAG.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.SK_1932.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.SK_1938.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.SK_1945.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.SK_1955.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.VA_1913.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.VA_1945.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.VA_2000.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_2005.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.ATR.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.BUR.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.CON.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/ST_2010.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.ATR.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.BUR.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.CON.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.COR.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.LAG.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.SK_1932.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.SK_1938.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.SK_1945.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.VA_2000.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/VA_1913.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.ATR.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.BUR.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.CON.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.COR.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.LAG.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.SK_1932.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.SK_1938.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.SK_1945.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.SK_1955.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.VA_1913.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.VA_2000.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/VA_1945.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.ATR.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.BUR.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.CON.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.RB_2000.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.SK_1913.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.SK_1932.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.SK_1938.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.SK_1945.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.SK_1999.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.VA_2006.fst.txt',
#        '../../results_5e5/out_fst/VA_2000.VA_2016.fst.txt',
#        '../../results_5e5/out_fst/VA_2006.ATR.fst.txt',
#        '../../results_5e5/out_fst/VA_2006.BUR.fst.txt',
#        '../../results_5e5/out_fst/VA_2006.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/VA_2006.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/VA_2006.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/VA_2006.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/VA_2006.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.ATR.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.BUR.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.CON.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.RB_2006.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.RB_2016.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.SK_1992.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.SK_2008.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.SK_2015.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.ST_1913.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.ST_1936.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.ST_1945.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.ST_1955.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.ST_2000.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.ST_2010.fst.txt',
#        '../../results_5e5/out_fst/VA_2016.VA_2006.fst.txt'], dtype='<U49')

# %%
Fst_dataframe = data.fillna(0) + data.fillna(0).T

# %% [markdown]
# make 2D matrix

# %%
mask = np.zeros_like(Fst_dataframe)
mask[np.triu_indices_from(Fst_dataframe,1)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(30,30))
    ax = sns.heatmap(Fst_dataframe, annot=True, fmt=".3f", mask=mask)
plt.yticks(rotation=0)
plt.xticks(rotation=90)

#plt.rcParams['figure.figsize']=(20,20) #rescale figures
#sns.heatmap(dfW)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5]),
#  <a list of 30 Text major ticklabel objects>)
